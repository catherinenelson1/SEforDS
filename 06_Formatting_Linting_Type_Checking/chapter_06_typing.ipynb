# %% [markdown]
# # Linting, Formatting and Type Checking
#
# ## Type Checking

# %%
import math

my_float = '100'
print(math.sqrt(my_float))

# %%
my_variable = 10

type(my_variable)

# %%
my_variable = 'hello'

type(my_variable)
